# %% [markdown]
# # Chương 1: Python vỡ lòng

# %% [markdown]
# Mỗi khối lệnh (code) có thể chạy nhiều lần theo thứ tự User gọi chạy

# %%
print (6 * 10)
print(5 + 7 * 2)

## Nhớ bấm Ctrl + Enter để xuống dòng
# Out:
# 60
# 19

# %%
10 >= 10
# Out:
# True

# %%
x = 5
y = 7
z = x + y
print(z)
# Out:
# 12

# %%
z / x
# Out:
# 2.4

# %%
# Chia lấy phân nguyên 
z // x
# Out:
# 2

# %%
# Kiểm tra định dạng type()
type(x), type(y), type(z)
# Out:
# (int, int, int)

# %%
x,y,z
# Out:
# (5, 7, 12)

# %%
a = z / x
b = z / y
c = str(b)

a,b,c
# Out:
# (2.4, 1.7142857142857142, '1.7142857142857142')

# %%
type(a), type(b), type(c)
# Out:
# (float, float, str)

# %%
r = "toi"
s = "ta"
t = "to"

r + s + t
# Out:
# 'toitato'

# %%
r * 5
# Out:
# 'toitoitoitoitoi'

# %%
N = 7

N % 2 == 1
# Out:
# True

# %%
for i in range(10):
  print(" "*(9 - i) + "*"*(2 * i + 1))
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %%
for i in range(10):
  print(" "*i + "*"*(2 *(9-i) + 1))
# Out:
# *******************
#  *****************
#   ***************
#    *************
#     ***********
#      *********
#       *******
#        *****
#         ***
#          *

# %%
for i in range(10):
  print(" "*i + "*"*20)
# Out:
# ********************
#  ********************
#   ********************
#    ********************
#     ********************
#      ********************
#       ********************
#        ********************
#         ********************
#          ********************

# %%
N = 6
for i in range(N):
  print(" "*(N - 1 - i) + "*"*(2*N))
# Out:
#      ************
#     ************
#    ************
#   ************
#  ************
# ************
