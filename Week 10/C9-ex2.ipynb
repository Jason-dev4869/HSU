# %% [markdown]
# # Chapter 9 - k-Means Clustering

# %% [markdown]
# ## Q1. Random data clustering

# %%
# import thư viện cần thiết


# Tạo 300 vectors dữ liệu ngẫu nhiên 5 chiều với giá trị ngẫu nhiên thuộc [-10, 10]


# Chuẩn hóa dữ liệu (mean=0, std=1)


# Phân dữ liệu thành 3 cụm


# Dùng PCA giảm dữ liệu xuống còn 2 chiều


# Lấy tọa độ tâm cụm trong không gian chuẩn hóa


# Chuyển tâm cụm sang không gian PCA 2D để vẽ


# Vẽ dữ liệu đã phân cụm + tâm cụm

# %% [markdown]
# ## Q2. Select k value

# %%
# Dùng Elbow method đề xuất k cho tập dữ liệu trên

# %%
# Dùng Silhouette method đề xuất k cho tập dữ liệu trên

# %% [markdown]
# ## Q3. Clustering the dataset with recommended k

# %%
# Phân cụm dữ liệu

# %%
# Vẽ biểu đồ scatter bằng dữ liệu sau khi phân cụm

# %% [markdown]
# ## Q4. Methods for generating initial k centers in the k-Means algorithm

# %% [markdown]
# Your answer

# %% [markdown]
# ## Q5. Using k-Means++

# %%
# import thư viện cần thiết


# Tạo 300 vectors dữ liệu ngẫu nhiên 5 chiều với giá trị ngẫu nhiên thuộc [-10, 10]


# Chuẩn hóa dữ liệu (mean=0, std=1)


# Phân dữ liệu thành 3 cụm dùng phương pháp k-Means++ để khởi tạo tâm các cụm


# Vẽ biểu đồ scatter bằng dữ liệu sau khi phân cụm với tâm màu đỏ
