# %% [markdown]
# # Chapter 9 - k-Means Clustering

# %% [markdown]
# ## Q1. Ecoli data clustering

# %%
# import thư viện cần thiết

# Đọc file ecoli.csv vào DataFrame 'df'
df = ...

# Loại bỏ các cột dữ liệu không dùng để phân cụm
X = ...

# Chuẩn hóa dữ liệu (mean=0, std=1)
X_scaled = ...

# Phân dữ liệu thành 8 cụm

kmeans = ...
clusters = ...

# Dùng PCA giảm dữ liệu xuống còn 2 chiều
X_pca = ...

# Lấy tọa độ tâm cụm trong không gian chuẩn hóa

# Chuyển tâm cụm sang không gian PCA 2D để vẽ

# HÌNH 1 — Vẽ dữ liệu gốc theo lớp

# HÌNH 2 — Vẽ dữ liệu đã phân cụm + tâm cụm

# %% [markdown]
# ## Q2. Select k value

# %%
# Dùng Elbow method đề xuất k cho dữ liệu ecoli

# %%
# Dùng Silhouette method đề xuất k cho dữ liệu ecoli

# %% [markdown]
# ## Q3. Clustering ecoli dataset with recommended k

# %%
# Phân cụm dữ liệu ecoli

# %%
# Vẽ biểu đồ scatter bằng dữ liệu gốc

# %%
# Vẽ biểu đồ scatter bằng dữ liệu sau khi phân cụm
