# %% [markdown]
# # Python Tuple Review Exercises

# %% [markdown]
# ## Exercise 1: Creation, Access, and Length
#
# 1. Create a tuple named `data_tuple` containing the string "Python", the integer 3, and the float 3.14. Ensure you also include a **one-item tuple** containing the string "single" within `data_tuple` (Remember the special syntax for a one-item tuple) [2].
# 2. Print the length of `data_tuple` [3].
# 3. Access and print the first element and the last element using positive and negative indexing, respectively [3].
# 4. Use slicing to print the elements from the second element up to (but not including) the last element [3].

# %% [markdown]
# ## Exercise 2: Handling Immutability
#
# You are given the tuple `fixed_items = ("alpha", "beta", "gamma")`. You need to change the middle element ("beta") to "delta".
# 1. Explain why direct modification is not possible (in a comment) [2].
# 2. Perform the change by converting the tuple to a list, modifying the list, and converting it back to a tuple. Print the final resulting tuple [2].

# %% [markdown]
# ## Exercise 3: Concatenation and Repetition
#
# Given `t1 = (1, 2)` and `t2 = (3, 4)`:
# 1. Concatenate (combine) `t1` and `t2` into a new tuple `t_combined` and print it [2].
# 2. Repeat `t1` three times into a new tuple `t_repeated` and print it [2].

# %% [markdown]
# ## Exercise 4: Packing and Unpacking
#
# 1. Create a tuple `colors` using **packing** containing "Red", "Green", "Blue", and "Yellow" [4].
# 2. **Unpack** the tuple such that the first element is assigned to variable `primary`, and the rest of the elements are assigned to a list variable `secondary_mix` (Hint: Use the asterisk `*` operator) [4]. Print both `primary` and `secondary_mix`.

# %% [markdown]
# ## Exercise 5: Iteration and Membership
#
# Given `numbers = (10, 20, 30, 40, 50)`:
# 1. Iterate through `numbers` using a `for` loop and print each element [2].
# 2. Check if the value 30 exists in `numbers` using the `in` keyword and print an appropriate message (e.g., "30 is present") [2].

# %% [markdown]
# ## Exercise 6: Using Tuple Methods
#
# Given `items = ("A", "B", "C", "A", "D", "A")`:
# 1. Use the appropriate method to count how many times "A" appears in the tuple and print the result [2].
# 2. Use the appropriate method to find the index of the first occurrence of "C" and print the result [4].
