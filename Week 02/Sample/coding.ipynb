# %% [markdown]
# <h3 align=center>
# Acoustics and coding
# </h3>
#
# ### General
#
# 1. Finish acoustics
# 1. Example
# 1. Spectrograms
# 1. Speech coding
#
# ### Acoustics
#
# Here are all the `import` statements we'll need for this notebook:

# %%
# %pip install sounddevice
# Out:
# Requirement already satisfied: sounddevice in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (0.5.2)
# Requirement already satisfied: CFFI>=1.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from sounddevice) (2.0.0)
# Requirement already satisfied: pycparser in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from CFFI>=1.0->sounddevice) (2.23)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pomegranate
# Out:
# Requirement already satisfied: pomegranate in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.22.2 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from pomegranate) (2.2.6)
# Requirement already satisfied: scipy>=1.6.2 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from pomegranate) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from pomegranate) (1.7.2)
# Requirement already satisfied: torch>=1.9.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from pomegranate) (2.7.1+cu118)
# Requirement already satisfied: apricot-select>=0.6.1 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from pomegranate) (0.6.1)
# Requirement already satisfied: networkx>=2.8.4 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from pomegranate) (3.3)
# Requirement already satisfied: numba>=0.43.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from apricot-select>=0.6.1->pomegranate) (0.62.0)
# Requirement already satisfied: tqdm>=4.24.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from apricot-select>=0.6.1->pomegranate) (4.67.1)
# Requirement already satisfied: nose in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from apricot-select>=0.6.1->pomegranate) (1.3.7)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from numba>=0.43.0->apricot-select>=0.6.1->pomegranate) (0.45.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from scikit-learn>=1.0.2->pomegranate) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from scikit-learn>=1.0.2->pomegranate) (3.6.0)
# Requirement already satisfied: filelock in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (4.15.0)
# Requirement already satisfied: setuptools in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (1.13.3)
# Requirement already satisfied: jinja2 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (3.1.4)
# Requirement already satisfied: fsspec in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from torch>=1.9.0->pomegranate) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.9.0->pomegranate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from jinja2->torch>=1.9.0->pomegranate) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python_speech_features
# Out:
# Requirement already satisfied: python_speech_features in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (0.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install hmmlearn
# Out:
# Requirement already satisfied: hmmlearn in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (0.3.3)
# Requirement already satisfied: numpy>=1.10 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from hmmlearn) (2.2.6)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from hmmlearn) (1.7.2)
# Requirement already satisfied: scipy>=0.19 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from hmmlearn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/jasonthedev0/micromamba/lib/python3.13/site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import speechtech as sp
from IPython.display import Audio
import scipy.signal as sig
import pylab
from scipy.io import wavfile
from sklearn import linear_model
import sounddevice as sd

# %% [markdown]
# We can look at the filtering effect of the vocal tract by recording different vowels we produce and the plotting the spectra:
#
# Chúng ta có thể xem xét hiệu ứng lọc của đường thanh quản bằng cách ghi lại các nguyên âm khác nhau mà chúng ta tạo ra và vẽ biểu đồ quang phổ:

# %%
fs,w = sp.record()

a,b = sp.spec(w,fs)
plt.plot(b[:10000],a[:10000])
plt.show()

Audio(w,rate=fs)

sd.play(w, samplerate=fs)
# Out:
# recording...
# finished recording

# %% [markdown]
# ### Example
#
# Let's do a schematic example of creating a complex sound.
#
# Chúng ta hãy cùng làm một ví dụ sơ đồ về cách tạo ra âm thanh phức tạp.
#
# Let's create a complex periodic wave and then concatenate it with a bit of white noise. This is as if we have a vowel *followed* by some fricative.
#
# Hãy tạo ra một sóng tuần hoàn phức tạp rồi nối nó với một chút nhiễu trắng. Điều này giống như chúng ta có một nguyên âm *theo sau* là một âm sát.

# %%
#a sine component
w1 = np.sin(np.arange(0,900*np.pi,.1))
#another sine component, higher frequency, lower amplitude
w2 = .5 * np.sin(np.arange(0,600*np.pi,.2))

Audio(w1,rate=len(w1))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sd.play(w1, samplerate=len(w1))

# %%
Audio(w2,rate=len(w2))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sd.play(w2, samplerate=len(w2))

# %%
#make sure they have the same lengths!
print(len(w1),len(w2))
print(w1, w2)
# Out:
# 28275 9425
# [ 0.          0.09983342  0.19866933 ... -0.23127522 -0.13299303
#  -0.03338203] [ 0.          0.09933467  0.19470917 ... -0.26372324 -0.17407277
#  -0.07748256]

# %%
#combine the two components
w3 = np.concatenate((w1, w2))
#Listen to it
Audio(w3,rate=len(w3))
sd.play(w3, samplerate=len(w3))

# %%
#make sure the spectrum is right!
a,b = sp.spec(w3,len(w3))
plt.plot(b,a)
plt.show()

# %%
#make some white noise
mean = 0
std = 1 
numsamples = 3000
wn = np.random.normal(mean,std,size=numsamples)

#show it
plt.plot(wn)
plt.show()

# %%
#set nyquist frequency
nyq = numsamples * 0.5

#set filter point
highcut = 800/nyq

#create filter
x,y = sig.butter(8,highcut,btype="highpass")

#apply filter in two passes
z = sig.filtfilt(x,y,wn)

#plot spectrum
a,b = sp.spec(z,numsamples)
plt.bar(b,a)
plt.show()

print(len(z))

Audio(z,rate=5000)

sd.play(z,samplerate=5000)
# Out:
# 3000

# %%
#concatenate
res = np.hstack([w3,z])

#play
Audio(res,rate=6000)
sd.play(res,samplerate=6000)

# %% [markdown]
# ### Spectrograms
#
# Making a spectrogram is easy in praat, but a little more difficult with `python`. First, we load in a wave file:
#
# Tạo một phổ đồ rất dễ dàng trong praat, nhưng hơi khó hơn một chút với `python`. Trước tiên, chúng ta tải vào một file âm thanh:

# %%
fs,w = wavfile.read('quick.wav')

Audio(w,rate=fs)
sd.play(w, samplerate=fs)

# %% [markdown]
# The `pylab` module includes a `specgram()` function. Some of the parameters are a bit mysterious, but here's how to use it.
#
# Mô-đun `pylab` bao gồm hàm `specgram()`. Một số tham số hơi khó hiểu, nhưng sau đây là cách sử dụng.

# %%
#make the spectrogram
pylab.specgram(
    w,
    Fs=fs,
    NFFT=int(fs*.01),
    cmap='Greys',
    sides='default',
    pad_to=2048
)
#only display up to 8000hz
pylab.axis(ymax=4000)
pylab.show()

# %% [markdown]
# ### Sampling and quantization
#
# We need to sample at a sufficient rate to detect higher frequencies. Here's a demo. Change the value of `y` to see the effect of sampling.
#
# Chúng ta cần lấy mẫu ở tốc độ đủ để phát hiện tần số cao hơn. Đây là bản demo. Thay đổi giá trị `y` để xem hiệu ứng của việc lấy mẫu.

# %%
y = 2
x = np.sin(np.arange(0,4*np.pi,y))
z = np.sin(np.arange(0,4*np.pi,.0001))
plt.plot(np.arange(0,4*np.pi,.0001),z)
plt.plot(np.arange(0,4*np.pi,y),x)
plt.stem(np.arange(0,4*np.pi,y),x,'r')
plt.show()

# %% [markdown]
# The other problem is *quantization*: how many distinct amplitudes can we distinguish? If we quantize in terms of binary *bits*, we can distinguish amplitudes like this:
#
# Bits | Amplitudes
# :---:|:---------:
# 1    | 2
# 2    | 4
# 3    | 8
# 4    | 16
# 5    | 32
# 6    | 64
# 7    | 128
# 8    | 256
# 9    | 512
# 10   | 1024
# 11   | 2048
#
# Here's another demo of this. Again, change the value of `y` to see the effect of different quantization choices.

# %%
y = 5
x = np.sin(np.arange(1,4*np.pi,.1))
z = y * x
z = z.round()
z = z/y
plt.plot(x)
plt.plot(z,'r')
plt.show()

# %% [markdown]
# When we consider efficiency of coding, another interesting possibility to consider is *delta code modulation*. Here's a demo of that:

# %%
x = np.sin(np.arange(0,4*np.pi,.1))
y = x[1:]-x[:-1]
x = x[:-1]
plt.plot(x)
plt.plot(y,'r')
plt.show()

# %% [markdown]
# ### Linear predictive coding (LPC)
#
# LPC is one simple way of encoding a waveform in a useful and compact way. The basic idea is that we do multiple regression on the wave samples so that we try to predict any particular sample from the $n$ samples that precede it.
#
# Imagine we have a wave $w$ with 100 samples. We can do a third-order LPC on $10$-sample windows. First we break up the wave into $10$-sample windows where this might be the first window:
#
# $$
# w_0\ w_1\ w_2\ w_3\ w_4\ w_5\ w_6\ w_7\ w_8\ w_9
# $$
#
# We want to predict each number from the three numbers that precede it. This means we have the following equations:
#
# $$
# \begin{array}{c}
# c_1 w_0 + c_2 w_1 + c_3 w_2 = w_3 \\
# c_1 w_1 + c_2 w_2 + c_3 w_3 = w_4 \\
# c_1 w_2 + c_2 w_3 + c_3 w_4 = w_5 \\
# c_1 w_3 + c_2 w_4 + c_3 w_5 = w_6 \\
# c_1 w_4 + c_2 w_5 + c_3 w_6 = w_7 \\
# c_1 w_5 + c_2 w_6 + c_3 w_7 = w_8 \\
# c_1 w_6 + c_2 w_7 + c_3 w_8 = w_9
# \end{array}
# $$
#
# What the *autoregression* does is solve for $c_1$, $c_2$, and $c_3$. What it means is that we can represent this window as those coefficients plus the first three values $w_0$, $w_1$, and $w_2$.
#
# Following is a little demo that takes an actual wave and does the same thing. Here, the windows are $30$ samples long and the order of the LPC is $10$.

# %%
fs,w = wavfile.read('quick.wav')

#results go in res
res = np.zeros([len(w)//30,10])
#counters
i = 0
j = 0
#loop for each 30-sample window
while i+30 < len(w):
    #lpc function dies with all 0s
    if all(w[i:i+30] == 0):
        res[j,:] = np.repeat(np.nan,10)
    else:
        res[j,:] = sp.lpc(w[i:i+30],9)
    i += 30
    j += 1

#get a range of color names
cmap = plt.get_cmap('jet')
colors = cmap(np.linspace(0,1.0,10))

#print each line with a different color
for i in range(10):
    plt.plot(res[:,i],color=colors[i])

#restrict limits
plt.ylim([-50,50])
plt.show()
print(len(w),res.shape)
# Out:
# 153856 (5128, 10)

# %% [markdown]
# LPC can then be used in the *opposite* direction, to econstruct a wave. Here's a really simple example where the reconstructed wave is just a sine wave. First, we make the wave and do the 4th-order autoregression.

# %%
x = np.sin(np.arange(0,200*np.pi,.1))
plt.plot(x[:1000])
plt.show()

#build regression data
d = np.zeros([len(x)-4,5])
d[:,0] = x[:-4]
d[:,1] = x[1:-3]
d[:,2] = x[2:-2]
d[:,3] = x[3:-1]
d[:,4] = x[4:]

r = linear_model.LinearRegression()
r.fit(d[:,:4],d[:,4])
r.coef_
# Out:
# array([-0.50198511, -0.00403072,  0.49396393,  0.98702306])

# %%
x[0:4]
# Out:
# array([0.        , 0.09983342, 0.19866933, 0.29552021])

# %% [markdown]
# Then we predict all values starting from the first four:

# %%
#array to store reconstituted wave
y = np.zeros([len(x),1])
#copy first four values
y[:4,0] = x[:4]
#calculate predicted values for all other values
for i in range(4,len(y)):
    y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))

#display first 1000 values
plt.plot(y[:1000,0])
plt.show()
# Out:
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# ...
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))
# /tmp/ipykernel_18900/3463803620.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i,0] = r.predict(y[i-4:i,0].reshape(1, -1))

# %% [markdown]
# This is pretty good, but notice that it's not perfect. Here's the sum of the error:

# %%
sum(abs(y[:,0]-x))
# Out:
# np.float64(3.73932033258492e-09)
