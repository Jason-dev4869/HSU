# %%
#Normal sorted

l = [[1,2], [5,3], [1,1], [7,4], [12,1.5]]
sorted(l)
# Out:
# [[1, 1], [1, 2], [5, 3], [7, 4], [12, 1.5]]

# %%
sorted(l, key=lambda l:l[1])
# Out:
# [[1, 1], [12, 1.5], [1, 2], [5, 3], [7, 4]]
