# %% [markdown]
# # Chương 2 - Unit02

# %% [markdown]
# ## Chuỗi số có quy luật

# %%
# Tính a(n) = a(n - 1) + d

a1 = 5
d = 3

N = 10

n = 1
an = a1

# %%
n += 1
an = an + d

n, an
# Out:
# (8, 26)

# %%
a1 + (8-1)*d
# Out:
# 26

# %% [markdown]
# ## Sum a1 + a2 + ... + a(N)

# %%
sumall = 0
for n in range(1, N+1):
    an = a1 + (n-1)*d
    sumall = sumall + an
    print(n,an, "==>", sumall)

print(sumall)
# Out:
# 1 5 ==> 5
# 2 8 ==> 13
# 3 11 ==> 24
# 4 14 ==> 38
# 5 17 ==> 55
# 6 20 ==> 75
# 7 23 ==> 98
# 8 26 ==> 124
# 9 29 ==> 153
# 10 32 ==> 185
# 185

# %%
## Sigma [(k] ^ 2-k)
sumall = 0
for k in range(1,N+1):
    sumall = sumall + (k**2 - k)
    print(k, k**2 , sumall)
print("S10 = ", sumall, "by sumation")
# Out:
# 1 1 0
# 2 4 2
# 3 9 8
# 4 16 20
# 5 25 40
# 6 36 70
# 7 49 112
# 8 64 168
# 9 81 240
# 10 100 330
# S10 =  330 by sumation

# %%
sumKK = N*(N+1)*(2*N+1)/6
sumK = N*(N+1)/2
##The sum of the first N natural numbers is N*(N+1)/2 and the sum of
sumK, sumKK, sumKK - sumK
# Out:
# (55.0, 385.0, 330.0)

# %%
#Khoảng cách của A(3,5) --> B(5,7)
import math

math.sqrt(2**2 + 2**2)
# Out:
# 2.8284271247461903

# %%
taphopLe = (1,3,5)
taphopChan = (2,4,6)

# %%
type(taphopChan)
# Out:
# tuple

# %%
3 in taphopLe
# Out:
# True

# %% [markdown]
# ## Hàm - Function - Đồ Thị

# %%
! pip3 install numpy matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (2.2.5)
# Requirement already satisfied: matplotlib in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\chaun\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\chaun\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5,5,21)
y = 3*x+ 1

plt.plot(x,y)
plt.show()

# %%
x = np.linspace(-3,3,21)
fx = 10 + x**2

plt.plot(x,fx)
plt.show()

# %%
gx = 3 + x

plt.plot(x,fx,x,gx)
plt.show()

# %%
gfx = 3 + fx

plt.plot(x,fx,x,gx,x,gfx)
plt.show()

# %%
math.log2(2**10)
# Out:
# 10.0

# %%
## (a) y1 = 3^x, y2 = 3^(x-1)+2
x = np.linspace(-1,2,301)
y1 = 3**x
y2 = 3**(x - 1) + 2

# For visualization
graph1, = plt.plot(x,y1)
graph2, = plt.plot(x,y2)

plt.legend(handles=(graph1,graph2), labels=(r'$y=3^x$',r'$y=3^{x-1}+2$'))
plt.show()

# %%
# (b) y2 = 2**(-x-2)
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1,2,21)
y1 = 2**(-x)
y2 = 2**(-x-2)

#For visulization
graph1, = plt.plot(x,y1)
graph2, = plt.plot(x,y2)
plt.legend(handles=(graph1,graph2), labels=(r'$y=2^{-x}$',r'$y=2^{-x-2}$'))
plt.show()
