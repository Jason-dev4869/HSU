# %%
#Import Library
import underthesea as us

sentence = "Có thằng nhóc chơi bóng đá vì quá mệt mà đá ly nước trà đá"

#Tach tu
print(us.word_tokenize(sentence))
# Out:
# ['Có', 'thằng', 'nhóc', 'chơi', 'bóng đá', 'vì', 'quá', 'mệt', 'mà', 'đá ly', 'nước', 'trà', 'đá']

# %%
#Nhan loai tu
us.pos_tag(sentence)
# Out:
# [('Có', 'V'),
#  ('thằng', 'Nc'),
#  ('nhóc', 'N'),
#  ('chơi', 'V'),
#  ('bóng đá', 'N'),
#  ('vì', 'E'),
#  ('quá', 'R'),
#  ('mệt', 'A'),
#  ('mà', 'C'),
#  ('đá ly', 'V'),
#  ('nước', 'N'),
#  ('trà', 'N'),
#  ('đá', 'N')]

# %%
#Nhan dang thuc the
us.ner(sentence)
# Out:
# [('Có', 'V', 'B-VP', 'O'),
#  ('thằng', 'Nc', 'B-NP', 'O'),
#  ('nhóc', 'N', 'B-NP', 'O'),
#  ('chơi', 'V', 'B-VP', 'O'),
#  ('bóng đá', 'N', 'B-NP', 'O'),
#  ('vì', 'E', 'B-PP', 'O'),
#  ('quá', 'R', 'O', 'O'),
#  ('mệt', 'A', 'B-AP', 'O'),
#  ('mà', 'C', 'O', 'O'),
#  ('đá ly', 'V', 'B-VP', 'O'),
#  ('nước', 'N', 'B-NP', 'O'),
#  ('trà', 'N', 'B-NP', 'O'),
#  ('đá', 'N', 'B-NP', 'O')]
