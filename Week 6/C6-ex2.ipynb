# %% [markdown]
# # Chapter 6 - Neural Networks - Exercises

# %% [markdown]
# ### Exercise 1
#
# Using MLP Classifier to classify the iris dataset

# %% [markdown]
# ### Exercise 2
# Config the MLP Classifier as follows:
# - Three hidden layers: 10 neurons, 8 neurons, 6 neurons
# - Activation function: sigmoid
# - Maximum number of epochs: 100

# %% [markdown]
# ### Exercise 3
# Refer to the site: https://machinelearningcoban.com/2017/01/12/gradientdescent/
#
# Answer the following questions related to the function $f(x)$:
#
# - When does the function $f$ increase or decrease?
# - At what point $x_0$ does the function $f$ reach its local minimum value?
# - How does a large or small *Learning Rate* affect the process of finding a local minimum of the function $f$?
# - Suppose $ f'(x_0) = 0 $. If $f'(x_t) > 0$, how is $x_t$ related to $x_0$?
# - Why $ x_{t+1}=x_t - \alpha.f'(x_t)$, where $\alpha$ is the learning rate?

# %% [markdown]
# Your answer
